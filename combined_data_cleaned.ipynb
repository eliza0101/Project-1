# %%
#Import Dependencies
import pandas as pd
from pathlib import Path
import os

# %%
#import cleaned csv
cleaned_highest = '/Users/mac/CLASS/Project-1/clean_highest_gross_movies_df_clean..csv'
cleaned_IMDb = '/Users/mac/CLASS/Project-1/clean_IMDb_movie_data.csv'

# %%
#convert csv to df
cleaned_highest_df = pd.read_csv(cleaned_highest)
cleaned_IMDb_df = pd.read_csv(cleaned_IMDb)
# Out:
# /var/folders/bp/ghj2hg8n63ngp97nh99m0cr80000gn/T/ipykernel_6623/1479627001.py:3: DtypeWarning: Columns (8,9,10,13) have mixed types. Specify dtype option on import or set low_memory=False.
#   cleaned_IMDb_df = pd.read_csv(cleaned_IMDb)

# %%
#DISPLAY Highest df
cleaned_highest_df
# Out:
#      Unnamed: 0                                title  \
# 0           966      Snow White and the Seven Dwarfs
# 1           344                   Gone with the Wind
# 2           615                                Bambi
# 3           802       One Hundred and One Dalmatians
# 4           856                      The Jungle Book
# ..          ...                                  ...
# 995         146  Spider-Man: Across the Spider-Verse
# 996         138                               Fast X
# 997         872                           The Nun II
# 998         195                   The Little Mermaid
# 999         943              Insidious: The Red Door
#
#                                             Movie Info  \
# 0    Exiled into the dangerous forest by her wicked...
# 1    A sheltered and manipulative Southern belle an...
# 2    The story of a young deer growing up in the fo...
# 3    When a litter of Dalmatian puppies are abducte...
# 4    Bagheera the Panther and Baloo the Bear have a...
# ..                                                 ...
# 995  Miles Morales catapults across the Multiverse,...
# 996  Dom Toretto and his family are targeted by the...
# 997  1956 - France. A priest is murdered. An evil i...
# 998  A young mermaid makes a deal with a sea witch ...
# 999  The Lamberts must go deeper into The Further t...
#
#                              Distributor       budget  \
# 0    Walt Disney Studios Motion Pictures     211937.0
# 1              Metro-Goldwyn-Mayer (MGM)  130000000.0
# 2                     RKO Radio Pictures  150000000.0
# 3    Walt Disney Studios Motion Pictures   62000000.0
# 4    Walt Disney Studios Motion Pictures   85000000.0
# ..                                   ...          ...
# 995                    Columbia Pictures     312023.0
# 996                   Universal Pictures     272023.0
# 997                         Warner Bros.      62023.0
# 998  Walt Disney Studios Motion Pictures      42023.0
# 999                          Screen Gems      52023.0
#
#      Domestic Opening (in $)  Domestic Sales (in $)  \
# 0                  1499000.0            184925486.0
# 1                   151939.0            200882193.0
# 2                   211942.0            102247150.0
# 3                   251961.0            144880014.0
# 4                   181967.0            141843612.0
# ..                       ...                    ...
# 995              120663589.0            381311319.0
# 996               67017410.0            145960660.0
# 997               32603336.0             69222000.0
# 998               95578040.0            298172056.0
# 999               33013036.0             82156962.0
#
#      International Sales (in $)        gross  \
# 0                   184925486.0  184928542.0
# 1                   201500000.0  402382193.0
# 2                   165200000.0  267447150.0
# 3                    71000000.0  215880014.0
# 4                    64000000.0  205843612.0
# ..                          ...          ...
# 995                 308499543.0  689810862.0
# 996                 558749000.0  704709660.0
# 997                 135000000.0  204222000.0
# 998                 271420242.0  569592298.0
# 999                 106341657.0  188498619.0
#
#                                                  genre      runtime license  \
# 0                      ['Drama', 'Musical', 'Romance']   2 hr 7 min   PG-13
# 1                   ['Adventure', 'Mystery', 'Sci-Fi']   2 hr 4 min       R
# 2    ['Action', 'Drama', 'Mystery', 'Sci-Fi', 'Thri...  2 hr 44 min       R
# 3             ['Action', 'Crime', 'Drama', 'Thriller']  2 hr 21 min   PG-13
# 4                                ['Comedy', 'Romance']  2 hr 16 min   PG-13
# ..                                                 ...          ...     ...
# 995      ['Action', 'Adventure', 'Sci-Fi', 'Thriller']  2 hr 22 min   PG-13
# 996                  ['Action', 'Adventure', 'Sci-Fi']  2 hr 24 min   PG-13
# 997                               ['Action', 'Comedy']  1 hr 53 min   PG-13
# 998                   ['Drama', 'Romance', 'Thriller']   2 hr 5 min       R
# 999                ['Action', 'Adventure', 'Thriller']  1 hr 42 min       0
#
#     release_date  runtime_minutes
# 0     2001-05-18              127
# 1     2012-05-30              124
# 2     2017-10-04              164
# 3     1994-08-05              141
# 4     2006-12-05              136
# ..           ...              ...
# 995   2012-03-08              142
# 996   2007-06-28              144
# 997   2008-06-05              113
# 998   2015-02-11              125
# 999   1988-05-25              102
#
# [1000 rows x 14 columns]
