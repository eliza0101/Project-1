# %%
import pandas as pd
from pathlib import Path
import os

# %%
# Directory containing all need csv files
directory = '/Users/mac/CLASS/Project-1/Movie_Datasets'

# %%
# A list to contain all the dataframes 
dfs = []

# %%
# Loop through all the files in directory
for filename in os.listdir(directory):
    if filename.endswith(".csv"):
        filepath = os.path.join(directory, filename)
        
        # Read csv file into a DataFrame
        df = pd.read_csv(filepath)
        
        # Append DF to list
        dfs.append(df)

# Concatenate all DFs into a single DF
combined_df = pd.concat(dfs, ignore_index=True)

# Print combined DataFrame
combined_df
# Out:
#            movie_id                                    movie_name  year  \
# 0         tt5433140                                        Fast X  2023
# 1        tt11564570                                   Glass Onion  2022
# 2        tt10365998                                 Infinity Pool  2023
# 3        tt14138650                             The Pale Blue Eye  2022
# 4        tt15789492                                      Infiesto  2023
# ...             ...                                           ...   ...
# 1130899  tt27036537                         The Beauty of a Woman   NaN
# 1130900  tt27047718  Armandinho Muito Mais Que O Azul De Zanzibar  2021
# 1130901  tt27050530                                         Baraa   NaN
# 1130902  tt27052307                       Maserati: a Racing Life   NaN
# 1130903  tt27053625                                         Anwar   NaN
#
#         certificate  runtime                     genre rating  \
# ...

# %%
combined_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1130904 entries, 0 to 1130903
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count    Dtype
# ---  ------                      --------------    -----
#  0   movie_id                    1104900 non-null  object
#  1   movie_name                  1104888 non-null  object
#  2   year                        968160 non-null   object
#  3   certificate                 312573 non-null   object
#  4   runtime                     800430 non-null   object
#  5   genre                       1127904 non-null  object
#  6   rating                      715587 non-null   object
#  7   description                 1104900 non-null  object
#  8   director                    1045797 non-null  object
#  9   director_id                 1022793 non-null  object
#  10  star                        951816 non-null   object
#  11  star_id                     949326 non-null   object
# ...

# %%
combined_df.describe()
# Out:
#               votes   gross(in $)   Unnamed: 0         Year  \
# count  7.158210e+05  7.511700e+04  3000.000000  3000.000000
# mean   1.214262e+04  2.963822e+07   499.500000  2008.181000
# std    6.598877e+04  6.302977e+07   288.723115    10.582323
# min    5.000000e+00  1.000000e+00     0.000000  1937.000000
# 25%    3.900000e+01  3.141700e+05   249.750000  2002.000000
# 50%    2.050000e+02  5.017971e+06   499.500000  2010.000000
# 75%    1.475000e+03  3.105360e+07   749.250000  2016.000000
# max    2.675531e+06  9.366622e+08   999.000000  2023.000000
#
#        Domestic Sales (in $)  International Sales (in $)  \
# count           3.000000e+03                3.000000e+03
# mean            1.646405e+08                2.640890e+08
# std             1.197142e+08                2.133136e+08
# min             6.752000e+03                2.450000e+07
# 25%             9.572506e+07                1.321190e+08
# 50%             1.349169e+08                1.941077e+08
# ...

# %%
combined_df.head()
# Out:
#      movie_id         movie_name  year certificate  runtime  \
# 0   tt5433140             Fast X  2023         NaN      NaN
# 1  tt11564570        Glass Onion  2022       PG-13  139 min
# 2  tt10365998      Infinity Pool  2023           R  117 min
# 3  tt14138650  The Pale Blue Eye  2022           R  128 min
# 4  tt15789492           Infiesto  2023       TV-MA   96 min
#
#                     genre rating  \
# 0  Action, Crime, Mystery    NaN
# 1    Comedy, Crime, Drama    7.2
# 2  Crime, Horror, Mystery    6.5
# 3  Crime, Horror, Mystery    6.6
# 4  Crime, Drama, Thriller    5.5
#
#                                          description            director  \
# 0  Dom Toretto and his family are targeted by the...     Louis Leterrier
# 1  Famed Southern detective Benoit Blanc travels ...        Rian Johnson
# 2  James and Em Foster are enjoying an all-inclus...  Brandon Cronenberg
# 3  A world-weary detective is hired to investigat...        Scott Cooper
# ...

# %%
combined_df.columns
# Out:
# Index(['movie_id', 'movie_name', 'year', 'certificate', 'runtime', 'genre',
#        'rating', 'description', 'director', 'director_id', 'star', 'star_id',
#        'votes', 'gross(in $)', 'Unnamed: 0', 'Title', 'Movie Info', 'Year',
#        'Distributor', 'Budget (in $)', 'Domestic Opening (in $)',
#        'Domestic Sales (in $)', 'International Sales (in $)',
#        'World Wide Sales (in $)', 'Release Date', 'Genre', 'Running Time',
#        'License', 'name', 'released', 'score', 'writer', 'country', 'budget',
#        'gross', 'company'],
#       dtype='object')
